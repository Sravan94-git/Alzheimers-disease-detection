# %%
import keras,os
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
import warnings 
from imblearn.over_sampling import SMOTE
warnings.filterwarnings("ignore")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_dir = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/train"
test_dir = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/test"

train_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.15,rotation_range=20,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,horizontal_flip=True,vertical_flip=True)
test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = train_dir,target_size = (128,128),seed=1,
                                                   class_mode = 'categorical',subset = 'training',batch_size = 32)

valid_dataset = train_datagen.flow_from_directory(directory = train_dir,target_size = (128,128),seed=1,
                                                   class_mode = 'categorical',subset = 'validation',batch_size = 32)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,target_size = (128,128),seed=1,
                                                class_mode = 'categorical',batch_size = 16)
# Out:
# Found 4355 images belonging to 4 classes.
# Found 766 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
import os
from distutils.dir_util import copy_tree, remove_tree

base_dir = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset"
root_dir = "./"
test_dir = os.path.join(base_dir, "train")
train_dir = os.path.join(base_dir, "test")
work_dir = os.path.join(root_dir, "dataset/")

if os.path.exists(work_dir):
    remove_tree(work_dir)

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'VeryMildDemented', 'NonDemented']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

# %%
zoomrange = [.9, 1.0]
brightness = [0.7, 1.3]

work_dr = ImageDataGenerator(rescale = 1./255, brightness_range=brightness, zoom_range=zoomrange, 
                             data_format="channels_last", fill_mode="constant", horizontal_flip=True)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=(128,128), 
                                             batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
train_data_gen.class_indices
# Out:
# {'MildDemented': 0,
#  'ModerateDemented': 1,
#  'NonDemented': 2,
#  'VeryMildDemented': 3}

# %%
train_data, train_labels = next(train_data_gen)

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (6400, 128, 128, 3) (6400, 4)

# %%
valid_dataset = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(128, 128),
    class_mode='categorical',
    batch_size=32,
    subset='validation'
)
# Out:
# Found 190 images belonging to 4 classes.

# %%
sm = SMOTE(random_state=42)
train_data, train_labels = sm.fit_resample(train_data.reshape(-1, 128 * 128 * 3), train_labels)
train_data = train_data.reshape(-1, 128, 128, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (12800, 128, 128, 3) (12800, 4)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.15, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
from keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Sequential
from keras.utils import to_categorical

classifier = Sequential()

classifier.add(Conv2D(32, (2, 2), input_shape=(128, 128, 3)))
classifier.add(Activation('relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

classifier.add(Conv2D(32, (2, 2)))
classifier.add(Activation('relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

classifier.add(Conv2D(64, (2, 2)))
classifier.add(Activation('relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Flatten())

classifier.add(Dense(64))
classifier.add(Activation('relu'))
classifier.add(Dropout(0.5))

classifier.add(Dense(4))
classifier.add(Activation('softmax'))

# %%
from tensorflow.keras.optimizers import Adam
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc')]
classifier.compile(optimizer='adam',
              loss=tf.losses.CategoricalCrossentropy(),
              metrics=METRICS)

classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 127, 127, 32)   │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 62, 62, 32)     │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 30, 30, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       921,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 4)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 934,724 (3.57 MB)
#  Trainable params: 934,724 (3.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
EPOCHS = 100
history1 = classifier.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=EPOCHS)
# Out:
# Epoch 1/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - acc: 0.8325 - loss: 0.3354 - val_acc: 0.8764 - val_loss: 0.3031
# Epoch 2/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8542 - loss: 0.3092 - val_acc: 0.8686 - val_loss: 0.3334
# Epoch 3/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8463 - loss: 0.3066 - val_acc: 0.8722 - val_loss: 0.3307
# Epoch 4/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8513 - loss: 0.3021 - val_acc: 0.8842 - val_loss: 0.3020
# Epoch 5/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.8519 - loss: 0.3118 - val_acc: 0.8819 - val_loss: 0.3047
# Epoch 6/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.8667 - loss: 0.2796 - val_acc: 0.8805 - val_loss: 0.3217
# Epoch 7/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8593 - loss: 0.2895 - val_acc: 0.8722 - val_loss: 0.3404
# Epoch 8/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8565 - loss: 0.2855 - val_acc: 0.8796 - val_loss: 0.3145
# Epoch 9/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8609 - loss: 0.2695 - val_acc: 0.8805 - val_loss: 0.3162
# Epoch 10/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8681 - loss: 0.2647 - val_acc: 0.8948 - val_loss: 0.2857
# Epoch 11/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8617 - loss: 0.2696 - val_acc: 0.8879 - val_loss: 0.3284
# Epoch 12/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8703 - loss: 0.2677 - val_acc: 0.8828 - val_loss: 0.3476
# Epoch 13/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8724 - loss: 0.2603 - val_acc: 0.8925 - val_loss: 0.2875
# Epoch 14/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8788 - loss: 0.2469 - val_acc: 0.8874 - val_loss: 0.3402
# Epoch 15/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8839 - loss: 0.2405 - val_acc: 0.8902 - val_loss: 0.3487
# Epoch 16/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8758 - loss: 0.2673 - val_acc: 0.8874 - val_loss: 0.3477
# Epoch 17/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8852 - loss: 0.2387 - val_acc: 0.8892 - val_loss: 0.3482
# Epoch 18/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8817 - loss: 0.2516 - val_acc: 0.8883 - val_loss: 0.3588
# Epoch 19/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.8961 - loss: 0.2384 - val_acc: 0.8892 - val_loss: 0.3588
# Epoch 20/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9008 - loss: 0.2176 - val_acc: 0.8975 - val_loss: 0.3253
# Epoch 21/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8982 - loss: 0.2272 - val_acc: 0.8906 - val_loss: 0.3663
# Epoch 22/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.8957 - loss: 0.2239 - val_acc: 0.8906 - val_loss: 0.3383
# Epoch 23/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9081 - loss: 0.2084 - val_acc: 0.8920 - val_loss: 0.3648
# Epoch 24/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9029 - loss: 0.2122 - val_acc: 0.8902 - val_loss: 0.4099
# Epoch 25/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9060 - loss: 0.2059 - val_acc: 0.8952 - val_loss: 0.3723
# Epoch 26/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9075 - loss: 0.2154 - val_acc: 0.8791 - val_loss: 0.4845
# Epoch 27/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9133 - loss: 0.2079 - val_acc: 0.8911 - val_loss: 0.4077
# Epoch 28/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9064 - loss: 0.2129 - val_acc: 0.8929 - val_loss: 0.4525
# Epoch 29/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9050 - loss: 0.2135 - val_acc: 0.8824 - val_loss: 0.4556
# Epoch 30/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9076 - loss: 0.1958 - val_acc: 0.8980 - val_loss: 0.4013
# Epoch 31/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9181 - loss: 0.1876 - val_acc: 0.8952 - val_loss: 0.4125
# Epoch 32/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9170 - loss: 0.1913 - val_acc: 0.8892 - val_loss: 0.4860
# Epoch 33/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9091 - loss: 0.2034 - val_acc: 0.8966 - val_loss: 0.3974
# Epoch 34/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9209 - loss: 0.1833 - val_acc: 0.8980 - val_loss: 0.4558
# Epoch 35/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9165 - loss: 0.2008 - val_acc: 0.8966 - val_loss: 0.3975
# Epoch 36/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9171 - loss: 0.1881 - val_acc: 0.8902 - val_loss: 0.3607
# Epoch 37/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9126 - loss: 0.1923 - val_acc: 0.8943 - val_loss: 0.3703
# Epoch 38/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9211 - loss: 0.1807 - val_acc: 0.8929 - val_loss: 0.4373
# Epoch 39/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9167 - loss: 0.1886 - val_acc: 0.8897 - val_loss: 0.3860
# Epoch 40/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9221 - loss: 0.1866 - val_acc: 0.8911 - val_loss: 0.4413
# Epoch 41/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9257 - loss: 0.1713 - val_acc: 0.8989 - val_loss: 0.4781
# Epoch 42/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9203 - loss: 0.1838 - val_acc: 0.9007 - val_loss: 0.3977
# Epoch 43/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9218 - loss: 0.1770 - val_acc: 0.8975 - val_loss: 0.4101
# Epoch 44/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9169 - loss: 0.1949 - val_acc: 0.8989 - val_loss: 0.4704
# Epoch 45/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9254 - loss: 0.1777 - val_acc: 0.8833 - val_loss: 0.4449
# Epoch 46/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9172 - loss: 0.1905 - val_acc: 0.8934 - val_loss: 0.3823
# Epoch 47/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9170 - loss: 0.2005 - val_acc: 0.8920 - val_loss: 0.3789
# Epoch 48/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9273 - loss: 0.1729 - val_acc: 0.8980 - val_loss: 0.4239
# Epoch 49/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9265 - loss: 0.1746 - val_acc: 0.8975 - val_loss: 0.4917
# Epoch 50/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9260 - loss: 0.1811 - val_acc: 0.8966 - val_loss: 0.4814
# Epoch 51/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9264 - loss: 0.1791 - val_acc: 0.8819 - val_loss: 0.4810
# Epoch 52/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9250 - loss: 0.1725 - val_acc: 0.8929 - val_loss: 0.5117
# Epoch 53/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9196 - loss: 0.1905 - val_acc: 0.8975 - val_loss: 0.4895
# Epoch 54/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9291 - loss: 0.1784 - val_acc: 0.8980 - val_loss: 0.4918
# Epoch 55/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9392 - loss: 0.1459 - val_acc: 0.8888 - val_loss: 0.5057
# Epoch 56/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9275 - loss: 0.1678 - val_acc: 0.8929 - val_loss: 0.4953
# Epoch 57/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9294 - loss: 0.1720 - val_acc: 0.8722 - val_loss: 0.6009
# Epoch 58/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9267 - loss: 0.1769 - val_acc: 0.8906 - val_loss: 0.4586
# Epoch 59/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9289 - loss: 0.1707 - val_acc: 0.8902 - val_loss: 0.5228
# Epoch 60/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9329 - loss: 0.1589 - val_acc: 0.8998 - val_loss: 0.4771
# Epoch 61/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9227 - loss: 0.1783 - val_acc: 0.8888 - val_loss: 0.5137
# Epoch 62/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9242 - loss: 0.1744 - val_acc: 0.8920 - val_loss: 0.5300
# Epoch 63/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9252 - loss: 0.1760 - val_acc: 0.8984 - val_loss: 0.5424
# Epoch 64/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9245 - loss: 0.1882 - val_acc: 0.8879 - val_loss: 0.4766
# Epoch 65/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9272 - loss: 0.1761 - val_acc: 0.8897 - val_loss: 0.5737
# Epoch 66/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9213 - loss: 0.1917 - val_acc: 0.8833 - val_loss: 0.5656
# Epoch 67/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9273 - loss: 0.1666 - val_acc: 0.8915 - val_loss: 0.5613
# Epoch 68/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9299 - loss: 0.1733 - val_acc: 0.8975 - val_loss: 0.4661
# Epoch 69/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9299 - loss: 0.1674 - val_acc: 0.8796 - val_loss: 0.6357
# Epoch 70/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9316 - loss: 0.1649 - val_acc: 0.9021 - val_loss: 0.4938
# Epoch 71/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9297 - loss: 0.1718 - val_acc: 0.8961 - val_loss: 0.5484
# Epoch 72/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9405 - loss: 0.1397 - val_acc: 0.8888 - val_loss: 0.4759
# Epoch 73/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - acc: 0.9271 - loss: 0.1763 - val_acc: 0.8966 - val_loss: 0.4930
# Epoch 74/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9367 - loss: 0.1538 - val_acc: 0.8929 - val_loss: 0.5951
# Epoch 75/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9365 - loss: 0.1524 - val_acc: 0.8984 - val_loss: 0.5562
# Epoch 76/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9373 - loss: 0.1465 - val_acc: 0.8892 - val_loss: 0.5810
# Epoch 77/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9316 - loss: 0.1610 - val_acc: 0.8998 - val_loss: 0.5278
# Epoch 78/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9396 - loss: 0.1494 - val_acc: 0.8961 - val_loss: 0.5885
# Epoch 79/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9325 - loss: 0.1626 - val_acc: 0.8915 - val_loss: 0.5953
# Epoch 80/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9373 - loss: 0.1663 - val_acc: 0.8998 - val_loss: 0.6210
# Epoch 81/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9395 - loss: 0.1565 - val_acc: 0.9017 - val_loss: 0.4364
# Epoch 82/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9315 - loss: 0.1575 - val_acc: 0.8911 - val_loss: 0.5308
# Epoch 83/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9348 - loss: 0.1590 - val_acc: 0.8892 - val_loss: 0.5582
# Epoch 84/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9437 - loss: 0.1386 - val_acc: 0.8971 - val_loss: 0.5548
# Epoch 85/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9338 - loss: 0.1536 - val_acc: 0.8837 - val_loss: 0.5423
# Epoch 86/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - acc: 0.9330 - loss: 0.1716 - val_acc: 0.8920 - val_loss: 0.5862
# Epoch 87/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9357 - loss: 0.1533 - val_acc: 0.8994 - val_loss: 0.5121
# Epoch 88/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9411 - loss: 0.1564 - val_acc: 0.8892 - val_loss: 0.5442
# Epoch 89/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9409 - loss: 0.1425 - val_acc: 0.8948 - val_loss: 0.5430
# Epoch 90/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9446 - loss: 0.1358 - val_acc: 0.8984 - val_loss: 0.4908
# Epoch 91/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9343 - loss: 0.1641 - val_acc: 0.8966 - val_loss: 0.5038
# Epoch 92/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9400 - loss: 0.1526 - val_acc: 0.8989 - val_loss: 0.5392
# Epoch 93/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9382 - loss: 0.1473 - val_acc: 0.8998 - val_loss: 0.5455
# Epoch 94/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9456 - loss: 0.1399 - val_acc: 0.8952 - val_loss: 0.5429
# Epoch 95/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - acc: 0.9319 - loss: 0.1660 - val_acc: 0.8975 - val_loss: 0.5786
# Epoch 96/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9413 - loss: 0.1428 - val_acc: 0.8943 - val_loss: 0.5898
# Epoch 97/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9401 - loss: 0.1493 - val_acc: 0.8943 - val_loss: 0.5474
# Epoch 98/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9434 - loss: 0.1405 - val_acc: 0.8856 - val_loss: 0.6524
# Epoch 99/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9405 - loss: 0.1521 - val_acc: 0.8888 - val_loss: 0.6733
# Epoch 100/100
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9384 - loss: 0.1483 - val_acc: 0.8892 - val_loss: 0.6368

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Make predictions
preds = classifier.predict(test_data)
preds_classes = np.argmax(preds, axis=1)
true_classes = np.argmax(test_labels, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(true_classes, preds_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASSES)

# Display the confusion matrix
disp.plot(cmap=plt.cm.Blues)
from IPython.display import FileLink

# Save the plot as a PNG image
output_file = "sine_wave_example.png"  # Save it in the current directory
plt.savefig(output_file, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# Create a download link to the saved image
FileLink(output_file)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /kaggle/working/sine_wave_example.png

# %%
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
# Save the plot as a PNG image
output_file = "sine_wave_example.png"  # Save it in the current directory
plt.savefig(output_file, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# Create a download link to the saved image
FileLink(output_file)
# Out:
# /kaggle/working/sine_wave_example.png

# %%
classifier.save('cnn_alzheimers_60.h5')
print("Model saved as cnn_alzheimers_60.h5")
# Out:
# Model saved as cnn_alzheimers_60.h5

# %%
import keras
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries
import matplotlib.pyplot as plt
model = load_model('cnn_alzheimers_60.h5')

# %%
# Define a function to preprocess the image
def preprocess_image(img_path, target_size=(128, 128)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.inception_v3.preprocess_input(img_array_expanded_dims)

image_path = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/test/VeryMildDemented/27 (11).jpg"
preprocessed_img = preprocess_image(image_path)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(preprocessed_img[0].astype('double'), 
                                         model.predict, top_labels=5, hide_color=0, num_samples=1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.title('Explanation for class: {}'.format(explanation.top_labels[0]))
# Save the plot as a PNG image
output_file = "sine_wave_example.png"  # Save it in the current directory
plt.savefig(output_file, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# Create a download link to the saved image
FileLink(output_file)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# /kaggle/working/sine_wave_example.png

# %%
from tensorflow.keras.utils import img_to_array,load_img
def read_image(file_path):
    print("[INFO] loading and preprocessing image…") 
    image = load_img(file_path, target_size=(128,128,1)) 
    image = img_to_array(image) 
    image = np.expand_dims(image, axis=0) 
    return image

# %%
def predict_proba(number):
    return [number[0],1-number[0]]

# %%
import time
def test_single_image(path):
    labels = ['MildDemented','ModerateDemented','NonDemented','VeryMildDemented']
    images = read_image(path)
    time.sleep(.5)
    bt_prediction = model.predict(images) 
    preds = predict_proba(bt_prediction)
    for idx, label, x in zip(range(0,6), labels , preds[0]):
        print("ID: {}, Label: {} {}%".format(idx, label, np.round(x*100,2) ))
    
    return load_img(path)

# %%
path = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/test/VeryMildDemented/27 (11).jpg"
test_single_image(path)
# Out:
# [INFO] loading and preprocessing image…
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# ID: 0, Label: MildDemented 0.0%
# ID: 1, Label: ModerateDemented 0.0%
# ID: 2, Label: NonDemented 0.0%
# ID: 3, Label: VeryMildDemented 100.0%
# <PIL.Image.Image image mode=RGB size=176x208>

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

predictions = classifier.predict(test_data)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = np.argmax(test_labels, axis=1)

report = classification_report(true_classes, predicted_classes, target_names=CLASSES)
print(report)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                   precision    recall  f1-score   support
#
#      NonDemented       0.92      0.98      0.95       474
# VeryMildDemented       1.00      1.00      1.00       473
#     MildDemented       0.85      0.84      0.85       507
# ModerateDemented       0.85      0.80      0.82       466
#
#         accuracy                           0.91      1920
#        macro avg       0.90      0.91      0.90      1920
#     weighted avg       0.90      0.91      0.90      1920
