# %%
pip install tensorflow==2.15.0

# %%
pip install --upgrade tensorflow-addons

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix


from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Flatten, BatchNormalization, Dense
import tensorflow as tf
import tensorflow_addons as tfa

print("TensorFlow Version:", tf.__version__)
# Out:
# 2024-11-25 18:24:19.154383: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-25 18:24:19.154446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-25 18:24:19.156470: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow Version: 2.15.0
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_dir = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/train"
test_dir = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/test"

train_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.15,rotation_range=20,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,horizontal_flip=True,vertical_flip=True)
test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = train_dir,target_size = (128,128),seed=1,
                                                   class_mode = 'categorical',subset = 'training',batch_size = 32)

valid_dataset = train_datagen.flow_from_directory(directory = train_dir,target_size = (128,128),seed=1,
                                                   class_mode = 'categorical',subset = 'validation',batch_size = 32)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,target_size = (128,128),seed=1,
                                                class_mode = 'categorical',batch_size = 16)
# Out:
# Found 4355 images belonging to 4 classes.
# Found 766 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
import os
from distutils.dir_util import copy_tree, remove_tree

base_dir = r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset"
root_dir = "./"
train_dir = os.path.join(base_dir, "/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/train")  # Corrected: train now points to train directory
test_dir = os.path.join(base_dir, "/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/test")    # Corrected: test now points to test directory
work_dir = os.path.join(root_dir, "dataset/")

if os.path.exists(work_dir):
    remove_tree(work_dir)
os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'VeryMildDemented', 'ModerateDemented', 'NonDemented']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
# Define augmentation parameters
ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"
WORK_DIR = './dataset/'
DIM = (176, 176)

# Create ImageDataGenerator
work_dr = ImageDataGenerator(
    rescale = 1./255, 
    brightness_range=BRIGHT_RANGE, 
    zoom_range=ZOOM, 
    data_format=DATA_FORMAT, 
    fill_mode=FILL_MODE, 
    horizontal_flip=HORZ_FLIP
)

# Generate augmented data
train_data_gen = work_dr.flow_from_directory(
    directory=WORK_DIR, 
    target_size=DIM, 
    batch_size=6500, 
    shuffle=False
)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):

    labels =dict(zip([0,1,2,3], CLASSES))

    x,y = generator.next()
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
show_images(train_data_gen)

# %%
train_data, train_labels = train_data_gen.next()

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
import tensorflow_addons as tfa
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications import DenseNet121

densenet_model = DenseNet121(input_shape=(176, 176, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
# Freeze layers in the base model
for layer in densenet_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
custom_densenet_model = Sequential([
    densenet_model,
    Dropout(0.5),
    GlobalAveragePooling2D(),
    Flatten(),
    BatchNormalization(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    BatchNormalization(),
    Dense(4, activation='softmax')        
], name="densenet_cnn_model")

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'),
           tfa.metrics.F1Score(num_classes=4)]

custom_densenet_model.compile(optimizer='rmsprop',loss=tf.losses.CategoricalCrossentropy(),metrics=METRICS)

custom_densenet_model.summary()
# Out:
# Model: "densenet_cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 5, 5, 1024)        7037504
#
#  dropout (Dropout)           (None, 5, 5, 1024)        0
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  batch_normalization_4 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 7742980 (29.54 MB)
# Trainable params: 701508 (2.68 MB)
# Non-trainable params: 7041472 (26.86 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Define callbacks
CALLBACKS = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_accuracy'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5)
]

EPOCHS = 100
history = custom_densenet_model.fit(
    train_data, 
    train_labels,
    validation_data=(val_data, val_labels),
    callbacks=CALLBACKS,
    epochs=EPOCHS
)
# Out:
# Epoch 1/100
# 2024-11-25 18:29:44.083655: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indensenet_cnn_model/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732559388.075441     144 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 256/256 [==============================] - 30s 75ms/step - loss: 1.3783 - acc: 0.4164 - auc: 0.6868 - f1_score: 0.4138 - val_loss: 0.7658 - val_acc: 0.6284 - val_auc: 0.8900 - val_f1_score: 0.6035 - lr: 0.0010
# Epoch 2/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.8880 - acc: 0.5992 - auc: 0.8581 - f1_score: 0.5958 - val_loss: 0.6316 - val_acc: 0.7017 - val_auc: 0.9253 - val_f1_score: 0.6872 - lr: 0.0010
# Epoch 3/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.7753 - acc: 0.6519 - auc: 0.8922 - f1_score: 0.6506 - val_loss: 0.5729 - val_acc: 0.7275 - val_auc: 0.9376 - val_f1_score: 0.7208 - lr: 0.0010
# Epoch 4/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.7154 - acc: 0.6932 - auc: 0.9101 - f1_score: 0.6923 - val_loss: 0.5591 - val_acc: 0.7539 - val_auc: 0.9420 - val_f1_score: 0.7507 - lr: 0.0010
# Epoch 5/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6610 - acc: 0.7194 - auc: 0.9226 - f1_score: 0.7186 - val_loss: 0.5055 - val_acc: 0.7788 - val_auc: 0.9548 - val_f1_score: 0.7756 - lr: 0.0010
# Epoch 6/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6304 - acc: 0.7319 - auc: 0.9302 - f1_score: 0.7311 - val_loss: 0.4707 - val_acc: 0.7920 - val_auc: 0.9600 - val_f1_score: 0.7877 - lr: 0.0010
# Epoch 7/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6019 - acc: 0.7438 - auc: 0.9355 - f1_score: 0.7425 - val_loss: 0.4459 - val_acc: 0.8169 - val_auc: 0.9665 - val_f1_score: 0.8150 - lr: 0.0010
# Epoch 8/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5729 - acc: 0.7642 - auc: 0.9424 - f1_score: 0.7630 - val_loss: 0.4136 - val_acc: 0.8242 - val_auc: 0.9695 - val_f1_score: 0.8221 - lr: 0.0010
# Epoch 9/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5359 - acc: 0.7855 - auc: 0.9491 - f1_score: 0.7847 - val_loss: 0.4134 - val_acc: 0.8271 - val_auc: 0.9698 - val_f1_score: 0.8261 - lr: 0.0010
# Epoch 10/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5236 - acc: 0.7911 - auc: 0.9519 - f1_score: 0.7903 - val_loss: 0.4011 - val_acc: 0.8213 - val_auc: 0.9714 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 11/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4976 - acc: 0.7992 - auc: 0.9561 - f1_score: 0.7988 - val_loss: 0.3687 - val_acc: 0.8413 - val_auc: 0.9756 - val_f1_score: 0.8391 - lr: 0.0010
# Epoch 12/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5031 - acc: 0.8029 - auc: 0.9556 - f1_score: 0.8022 - val_loss: 0.3643 - val_acc: 0.8569 - val_auc: 0.9765 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 13/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4658 - acc: 0.8121 - auc: 0.9615 - f1_score: 0.8110 - val_loss: 0.3363 - val_acc: 0.8584 - val_auc: 0.9795 - val_f1_score: 0.8569 - lr: 0.0010
# Epoch 14/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4476 - acc: 0.8292 - auc: 0.9643 - f1_score: 0.8286 - val_loss: 0.3271 - val_acc: 0.8613 - val_auc: 0.9808 - val_f1_score: 0.8603 - lr: 0.0010
# Epoch 15/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4398 - acc: 0.8306 - auc: 0.9657 - f1_score: 0.8300 - val_loss: 0.3110 - val_acc: 0.8755 - val_auc: 0.9827 - val_f1_score: 0.8744 - lr: 0.0010
# Epoch 16/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4300 - acc: 0.8326 - auc: 0.9670 - f1_score: 0.8319 - val_loss: 0.2934 - val_acc: 0.8848 - val_auc: 0.9842 - val_f1_score: 0.8836 - lr: 0.0010
# Epoch 17/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4263 - acc: 0.8380 - auc: 0.9674 - f1_score: 0.8375 - val_loss: 0.2961 - val_acc: 0.8784 - val_auc: 0.9843 - val_f1_score: 0.8770 - lr: 0.0010
# Epoch 18/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4110 - acc: 0.8402 - auc: 0.9697 - f1_score: 0.8397 - val_loss: 0.2960 - val_acc: 0.8750 - val_auc: 0.9838 - val_f1_score: 0.8737 - lr: 0.0010
# Epoch 19/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3837 - acc: 0.8553 - auc: 0.9729 - f1_score: 0.8547 - val_loss: 0.2953 - val_acc: 0.8804 - val_auc: 0.9836 - val_f1_score: 0.8791 - lr: 0.0010
# Epoch 20/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3901 - acc: 0.8521 - auc: 0.9725 - f1_score: 0.8516 - val_loss: 0.2741 - val_acc: 0.8892 - val_auc: 0.9862 - val_f1_score: 0.8880 - lr: 0.0010
# Epoch 21/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3759 - acc: 0.8593 - auc: 0.9742 - f1_score: 0.8587 - val_loss: 0.2856 - val_acc: 0.8867 - val_auc: 0.9848 - val_f1_score: 0.8868 - lr: 0.0010
# Epoch 22/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3868 - acc: 0.8595 - auc: 0.9729 - f1_score: 0.8593 - val_loss: 0.2609 - val_acc: 0.9014 - val_auc: 0.9877 - val_f1_score: 0.9002 - lr: 0.0010
# Epoch 23/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3715 - acc: 0.8643 - auc: 0.9748 - f1_score: 0.8639 - val_loss: 0.2707 - val_acc: 0.8936 - val_auc: 0.9866 - val_f1_score: 0.8917 - lr: 0.0010
# Epoch 24/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3637 - acc: 0.8684 - auc: 0.9757 - f1_score: 0.8680 - val_loss: 0.2616 - val_acc: 0.8994 - val_auc: 0.9874 - val_f1_score: 0.8991 - lr: 0.0010
# Epoch 25/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3529 - acc: 0.8719 - auc: 0.9771 - f1_score: 0.8718 - val_loss: 0.2465 - val_acc: 0.8970 - val_auc: 0.9887 - val_f1_score: 0.8965 - lr: 0.0010
# Epoch 26/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3391 - acc: 0.8778 - auc: 0.9786 - f1_score: 0.8775 - val_loss: 0.2405 - val_acc: 0.9053 - val_auc: 0.9893 - val_f1_score: 0.9043 - lr: 0.0010
# Epoch 27/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3367 - acc: 0.8793 - auc: 0.9788 - f1_score: 0.8789 - val_loss: 0.2450 - val_acc: 0.9058 - val_auc: 0.9888 - val_f1_score: 0.9047 - lr: 0.0010
# Epoch 28/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3377 - acc: 0.8795 - auc: 0.9788 - f1_score: 0.8793 - val_loss: 0.2312 - val_acc: 0.9121 - val_auc: 0.9902 - val_f1_score: 0.9113 - lr: 0.0010
# Epoch 29/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3194 - acc: 0.8871 - auc: 0.9807 - f1_score: 0.8868 - val_loss: 0.2265 - val_acc: 0.9106 - val_auc: 0.9905 - val_f1_score: 0.9099 - lr: 0.0010
# Epoch 30/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3172 - acc: 0.8834 - auc: 0.9814 - f1_score: 0.8833 - val_loss: 0.2264 - val_acc: 0.9106 - val_auc: 0.9905 - val_f1_score: 0.9098 - lr: 0.0010
# Epoch 31/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3229 - acc: 0.8860 - auc: 0.9802 - f1_score: 0.8855 - val_loss: 0.2259 - val_acc: 0.9111 - val_auc: 0.9903 - val_f1_score: 0.9104 - lr: 0.0010
# Epoch 32/100
# 256/256 [==============================] - 13s 52ms/step - loss: 0.3112 - acc: 0.8873 - auc: 0.9818 - f1_score: 0.8872 - val_loss: 0.2217 - val_acc: 0.9136 - val_auc: 0.9911 - val_f1_score: 0.9131 - lr: 0.0010
# Epoch 33/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2978 - acc: 0.8942 - auc: 0.9830 - f1_score: 0.8939 - val_loss: 0.2208 - val_acc: 0.9170 - val_auc: 0.9909 - val_f1_score: 0.9162 - lr: 0.0010
# Epoch 34/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2993 - acc: 0.8937 - auc: 0.9831 - f1_score: 0.8934 - val_loss: 0.2158 - val_acc: 0.9224 - val_auc: 0.9913 - val_f1_score: 0.9216 - lr: 0.0010
# Epoch 35/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2967 - acc: 0.8953 - auc: 0.9834 - f1_score: 0.8951 - val_loss: 0.2181 - val_acc: 0.9199 - val_auc: 0.9909 - val_f1_score: 0.9191 - lr: 0.0010
# Epoch 36/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2986 - acc: 0.8948 - auc: 0.9826 - f1_score: 0.8945 - val_loss: 0.2190 - val_acc: 0.9141 - val_auc: 0.9909 - val_f1_score: 0.9133 - lr: 0.0010
# Epoch 37/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2899 - acc: 0.8977 - auc: 0.9836 - f1_score: 0.8976 - val_loss: 0.2189 - val_acc: 0.9160 - val_auc: 0.9908 - val_f1_score: 0.9148 - lr: 0.0010
# Epoch 38/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2906 - acc: 0.8990 - auc: 0.9840 - f1_score: 0.8988 - val_loss: 0.2191 - val_acc: 0.9150 - val_auc: 0.9910 - val_f1_score: 0.9140 - lr: 0.0010
# Epoch 39/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2758 - acc: 0.8990 - auc: 0.9854 - f1_score: 0.8990 - val_loss: 0.2224 - val_acc: 0.9087 - val_auc: 0.9908 - val_f1_score: 0.9077 - lr: 0.0010
# Epoch 40/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2623 - acc: 0.9103 - auc: 0.9861 - f1_score: 0.9099 - val_loss: 0.2039 - val_acc: 0.9165 - val_auc: 0.9922 - val_f1_score: 0.9158 - lr: 2.0000e-04
# Epoch 41/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2655 - acc: 0.9077 - auc: 0.9860 - f1_score: 0.9075 - val_loss: 0.2003 - val_acc: 0.9189 - val_auc: 0.9924 - val_f1_score: 0.9183 - lr: 2.0000e-04
# Epoch 42/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2513 - acc: 0.9144 - auc: 0.9874 - f1_score: 0.9143 - val_loss: 0.1983 - val_acc: 0.9243 - val_auc: 0.9926 - val_f1_score: 0.9238 - lr: 2.0000e-04
# Epoch 43/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2422 - acc: 0.9125 - auc: 0.9883 - f1_score: 0.9123 - val_loss: 0.1966 - val_acc: 0.9253 - val_auc: 0.9925 - val_f1_score: 0.9246 - lr: 2.0000e-04
# Epoch 44/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2308 - acc: 0.9210 - auc: 0.9893 - f1_score: 0.9208 - val_loss: 0.1959 - val_acc: 0.9243 - val_auc: 0.9927 - val_f1_score: 0.9238 - lr: 2.0000e-04
# Epoch 45/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2432 - acc: 0.9161 - auc: 0.9877 - f1_score: 0.9159 - val_loss: 0.1910 - val_acc: 0.9268 - val_auc: 0.9928 - val_f1_score: 0.9263 - lr: 2.0000e-04
# Epoch 46/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2440 - acc: 0.9172 - auc: 0.9880 - f1_score: 0.9172 - val_loss: 0.1895 - val_acc: 0.9282 - val_auc: 0.9929 - val_f1_score: 0.9278 - lr: 2.0000e-04
# Epoch 47/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2360 - acc: 0.9147 - auc: 0.9889 - f1_score: 0.9144 - val_loss: 0.1934 - val_acc: 0.9229 - val_auc: 0.9929 - val_f1_score: 0.9224 - lr: 2.0000e-04
# Epoch 48/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2130 - acc: 0.9252 - auc: 0.9907 - f1_score: 0.9251 - val_loss: 0.1870 - val_acc: 0.9297 - val_auc: 0.9932 - val_f1_score: 0.9291 - lr: 2.0000e-04
# Epoch 49/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2257 - acc: 0.9255 - auc: 0.9893 - f1_score: 0.9254 - val_loss: 0.1915 - val_acc: 0.9277 - val_auc: 0.9931 - val_f1_score: 0.9271 - lr: 2.0000e-04
# Epoch 50/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2341 - acc: 0.9174 - auc: 0.9886 - f1_score: 0.9171 - val_loss: 0.1908 - val_acc: 0.9282 - val_auc: 0.9932 - val_f1_score: 0.9276 - lr: 2.0000e-04
# Epoch 51/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2112 - acc: 0.9288 - auc: 0.9906 - f1_score: 0.9287 - val_loss: 0.1898 - val_acc: 0.9297 - val_auc: 0.9932 - val_f1_score: 0.9291 - lr: 2.0000e-04
# Epoch 52/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2191 - acc: 0.9244 - auc: 0.9899 - f1_score: 0.9243 - val_loss: 0.1867 - val_acc: 0.9287 - val_auc: 0.9932 - val_f1_score: 0.9282 - lr: 2.0000e-04
# Epoch 53/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2302 - acc: 0.9244 - auc: 0.9890 - f1_score: 0.9243 - val_loss: 0.1854 - val_acc: 0.9292 - val_auc: 0.9935 - val_f1_score: 0.9286 - lr: 2.0000e-04
# Epoch 54/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2291 - acc: 0.9196 - auc: 0.9895 - f1_score: 0.9194 - val_loss: 0.1883 - val_acc: 0.9282 - val_auc: 0.9932 - val_f1_score: 0.9276 - lr: 2.0000e-04
# Epoch 55/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2217 - acc: 0.9269 - auc: 0.9895 - f1_score: 0.9268 - val_loss: 0.1873 - val_acc: 0.9302 - val_auc: 0.9935 - val_f1_score: 0.9297 - lr: 2.0000e-04
# Epoch 56/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2082 - acc: 0.9316 - auc: 0.9905 - f1_score: 0.9316 - val_loss: 0.1857 - val_acc: 0.9272 - val_auc: 0.9936 - val_f1_score: 0.9267 - lr: 2.0000e-04
# Epoch 57/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1937 - acc: 0.9332 - auc: 0.9919 - f1_score: 0.9331 - val_loss: 0.1812 - val_acc: 0.9307 - val_auc: 0.9938 - val_f1_score: 0.9301 - lr: 2.0000e-04
# Epoch 58/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2025 - acc: 0.9318 - auc: 0.9912 - f1_score: 0.9316 - val_loss: 0.1791 - val_acc: 0.9287 - val_auc: 0.9940 - val_f1_score: 0.9282 - lr: 2.0000e-04
# Epoch 59/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2141 - acc: 0.9291 - auc: 0.9906 - f1_score: 0.9290 - val_loss: 0.1792 - val_acc: 0.9316 - val_auc: 0.9938 - val_f1_score: 0.9313 - lr: 2.0000e-04
# Epoch 60/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2142 - acc: 0.9285 - auc: 0.9904 - f1_score: 0.9283 - val_loss: 0.1765 - val_acc: 0.9355 - val_auc: 0.9940 - val_f1_score: 0.9351 - lr: 2.0000e-04
# Epoch 61/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2027 - acc: 0.9287 - auc: 0.9910 - f1_score: 0.9286 - val_loss: 0.1736 - val_acc: 0.9346 - val_auc: 0.9942 - val_f1_score: 0.9341 - lr: 2.0000e-04
# Epoch 62/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1962 - acc: 0.9336 - auc: 0.9917 - f1_score: 0.9334 - val_loss: 0.1756 - val_acc: 0.9365 - val_auc: 0.9939 - val_f1_score: 0.9361 - lr: 2.0000e-04
# Epoch 63/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1887 - acc: 0.9360 - auc: 0.9922 - f1_score: 0.9360 - val_loss: 0.1765 - val_acc: 0.9370 - val_auc: 0.9939 - val_f1_score: 0.9365 - lr: 2.0000e-04
# Epoch 64/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1946 - acc: 0.9351 - auc: 0.9917 - f1_score: 0.9349 - val_loss: 0.1772 - val_acc: 0.9351 - val_auc: 0.9940 - val_f1_score: 0.9346 - lr: 2.0000e-04
# Epoch 65/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1983 - acc: 0.9343 - auc: 0.9918 - f1_score: 0.9343 - val_loss: 0.1803 - val_acc: 0.9331 - val_auc: 0.9939 - val_f1_score: 0.9326 - lr: 2.0000e-04
# Epoch 66/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1937 - acc: 0.9366 - auc: 0.9919 - f1_score: 0.9366 - val_loss: 0.1774 - val_acc: 0.9360 - val_auc: 0.9941 - val_f1_score: 0.9356 - lr: 2.0000e-04
# Epoch 67/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2051 - acc: 0.9355 - auc: 0.9907 - f1_score: 0.9355 - val_loss: 0.1752 - val_acc: 0.9360 - val_auc: 0.9942 - val_f1_score: 0.9356 - lr: 4.0000e-05
# Epoch 68/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2001 - acc: 0.9332 - auc: 0.9909 - f1_score: 0.9332 - val_loss: 0.1741 - val_acc: 0.9360 - val_auc: 0.9942 - val_f1_score: 0.9356 - lr: 4.0000e-05
# Epoch 69/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1970 - acc: 0.9340 - auc: 0.9918 - f1_score: 0.9338 - val_loss: 0.1749 - val_acc: 0.9360 - val_auc: 0.9942 - val_f1_score: 0.9355 - lr: 4.0000e-05
# Epoch 70/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1908 - acc: 0.9374 - auc: 0.9918 - f1_score: 0.9373 - val_loss: 0.1734 - val_acc: 0.9360 - val_auc: 0.9943 - val_f1_score: 0.9356 - lr: 4.0000e-05
# Epoch 71/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1966 - acc: 0.9375 - auc: 0.9914 - f1_score: 0.9374 - val_loss: 0.1748 - val_acc: 0.9370 - val_auc: 0.9942 - val_f1_score: 0.9365 - lr: 4.0000e-05
# Epoch 72/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2014 - acc: 0.9347 - auc: 0.9907 - f1_score: 0.9346 - val_loss: 0.1736 - val_acc: 0.9365 - val_auc: 0.9943 - val_f1_score: 0.9361 - lr: 4.0000e-05
# Epoch 73/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2043 - acc: 0.9348 - auc: 0.9906 - f1_score: 0.9348 - val_loss: 0.1721 - val_acc: 0.9355 - val_auc: 0.9944 - val_f1_score: 0.9351 - lr: 4.0000e-05
# Epoch 74/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1911 - acc: 0.9332 - auc: 0.9922 - f1_score: 0.9331 - val_loss: 0.1727 - val_acc: 0.9370 - val_auc: 0.9943 - val_f1_score: 0.9366 - lr: 4.0000e-05
# Epoch 75/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1923 - acc: 0.9365 - auc: 0.9918 - f1_score: 0.9364 - val_loss: 0.1722 - val_acc: 0.9341 - val_auc: 0.9944 - val_f1_score: 0.9336 - lr: 4.0000e-05
# Epoch 76/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1886 - acc: 0.9375 - auc: 0.9923 - f1_score: 0.9374 - val_loss: 0.1711 - val_acc: 0.9346 - val_auc: 0.9944 - val_f1_score: 0.9341 - lr: 4.0000e-05
# Epoch 77/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1911 - acc: 0.9348 - auc: 0.9920 - f1_score: 0.9348 - val_loss: 0.1715 - val_acc: 0.9346 - val_auc: 0.9944 - val_f1_score: 0.9341 - lr: 4.0000e-05
# Epoch 78/100
# 256/256 [==============================] - 13s 52ms/step - loss: 0.1953 - acc: 0.9326 - auc: 0.9919 - f1_score: 0.9326 - val_loss: 0.1747 - val_acc: 0.9355 - val_auc: 0.9943 - val_f1_score: 0.9351 - lr: 4.0000e-05
# Epoch 79/100
# 256/256 [==============================] - 13s 52ms/step - loss: 0.1921 - acc: 0.9351 - auc: 0.9921 - f1_score: 0.9349 - val_loss: 0.1720 - val_acc: 0.9341 - val_auc: 0.9944 - val_f1_score: 0.9336 - lr: 4.0000e-05
# Epoch 80/100
# 256/256 [==============================] - 13s 52ms/step - loss: 0.1926 - acc: 0.9325 - auc: 0.9918 - f1_score: 0.9324 - val_loss: 0.1728 - val_acc: 0.9351 - val_auc: 0.9944 - val_f1_score: 0.9346 - lr: 4.0000e-05
# Epoch 81/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1933 - acc: 0.9336 - auc: 0.9923 - f1_score: 0.9335 - val_loss: 0.1739 - val_acc: 0.9355 - val_auc: 0.9943 - val_f1_score: 0.9351 - lr: 4.0000e-05
# Epoch 82/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1865 - acc: 0.9342 - auc: 0.9924 - f1_score: 0.9341 - val_loss: 0.1741 - val_acc: 0.9351 - val_auc: 0.9943 - val_f1_score: 0.9346 - lr: 8.0000e-06
# Epoch 83/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1866 - acc: 0.9364 - auc: 0.9923 - f1_score: 0.9363 - val_loss: 0.1755 - val_acc: 0.9370 - val_auc: 0.9942 - val_f1_score: 0.9365 - lr: 8.0000e-06
# Epoch 84/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2003 - acc: 0.9330 - auc: 0.9909 - f1_score: 0.9330 - val_loss: 0.1723 - val_acc: 0.9355 - val_auc: 0.9944 - val_f1_score: 0.9351 - lr: 8.0000e-06
# Epoch 85/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.1937 - acc: 0.9358 - auc: 0.9919 - f1_score: 0.9356 - val_loss: 0.1732 - val_acc: 0.9365 - val_auc: 0.9944 - val_f1_score: 0.9361 - lr: 8.0000e-06
# Epoch 86/100
# 256/256 [==============================] - 13s 52ms/step - loss: 0.2011 - acc: 0.9338 - auc: 0.9908 - f1_score: 0.9338 - val_loss: 0.1743 - val_acc: 0.9360 - val_auc: 0.9942 - val_f1_score: 0.9355 - lr: 8.0000e-06

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical

# Assuming val_data and val_labels are your validation datasets
predictions = custom_densenet_model.predict(val_data)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(val_labels, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[1, 2, 3, 4], yticklabels=[1, 2, 3, 4])
plt.title('Confusion Matrix')
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()
# Out:
# 64/64 [==============================] - 4s 37ms/step

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
custom_densenet_model.save('densenet_model.h5', save_format='h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# Use the model you trained earlier
predictions = custom_densenet_model.predict(test_data)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_labels, axis=1)
report = classification_report(true_classes, predicted_classes, target_names=CLASSES)
print(report)
# Out:
# 80/80 [==============================] - 3s 37ms/step
#                   precision    recall  f1-score   support
#
#      NonDemented       0.97      0.98      0.98       639
# VeryMildDemented       1.00      1.00      1.00       635
#     MildDemented       0.92      0.88      0.90       662
# ModerateDemented       0.88      0.91      0.89       624
#
#         accuracy                           0.94      2560
#        macro avg       0.94      0.94      0.94      2560
#     weighted avg       0.94      0.94      0.94      2560

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.models import load_model
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries


def preprocess_image(img_path, target_size=(176, 176)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array_expanded_dims)

image_path =r"/kaggle/input/dataset-alzheimer/Alzheimer_s Dataset/test/VeryMildDemented/27 (11).jpg"
preprocessed_img = preprocess_image(image_path)

explainer = lime_image.LimeImageExplainer()

explanation = explainer.explain_instance(preprocessed_img[0].astype('double'), 
                                         custom_densenet_model.predict, top_labels=5, hide_color=0, num_samples=1000)

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=False)

plt.figure(figsize=(8, 8))
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.title(f'Explanation for class: {explanation.top_labels[0]}')
plt.axis('off') 
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
